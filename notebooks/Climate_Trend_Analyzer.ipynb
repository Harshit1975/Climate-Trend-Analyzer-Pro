# %% [markdown]
# # Climate Trend Analyzer Notebook
# This notebook walks through synthetic data generation, cleaning, EDA, anomaly detection, and forecasting.

# %%
import pandas as pd
from pathlib import Path
from src.data_loader import load_climate_data, clean_climate_data
from src.eda import plot_time_series, plot_correlation_heatmap
from src.anomaly import detect_anomalies_zscore
from src.forecast import linear_trend_forecast

DATA_DIR = Path('data')
sample_file = DATA_DIR / 'sample_climate_data.csv'
df = load_climate_data(sample_file)
df = clean_climate_data(df)
df.head()
